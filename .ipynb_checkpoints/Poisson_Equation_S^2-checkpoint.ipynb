# %% [markdown]
# ### Solving Poisson Equation on S^2: $\Delta u = f$

# %%
import torch

from Basis import SPHBasis
from Problem import Problem_Sphere_Poisson
from Model import Model
from Net import Sphere_Net, SPH_Sphere_Net
import seaborn as sns
import matplotlib.pyplot as plt
import math
from spherical_harmonics import *

torch.manual_seed(0)
maxiter = 101
problem = Problem_Sphere_Poisson()


def construct_model(net):
    class Poisson1dModel(Model):
        def add_loss_history(self):
            self.loss_history.append([self.bc_loss, self.pde_loss, self.predict_error_value])

        def __init__(self):
            super().__init__(problem=problem, net=net, maxiter=maxiter)

        def inner_sample(self, num=1000):
            x = torch.randn(num, 3)
            x = x / (torch.norm(x, dim=1).reshape((-1, 1)))
            weidu = torch.acos(x[:, 2:3])
            jingdu = torch.atan(x[:, :1] / x[:, 1:2]) + math.pi / 2
            jingdu[:num // 2, 0] = jingdu[:num // 2, 0] + math.pi
            x = torch.cat([weidu, jingdu], dim=1)
            return x

        def bc_sample(self):
            return torch.tensor([[1., 1.]])

        def init_sample(self):
            pass

        def plot(self, net):
            weidu = torch.linspace(0, math.pi, 200, requires_grad=False)
            jingdu = torch.linspace(0, 2 * math.pi, 400, requires_grad=False)
            weidu, jingdu = torch.meshgrid(weidu, jingdu)
            location = torch.cat([weidu.reshape(-1, 1), jingdu.reshape(-1, 1)], dim=1)
            value = net(location)
            
            value = value.reshape((200, 400))
            
            fig, ax = plt.subplots(1, 1, figsize=(8, 6))
            sns.set()
            sns.heatmap(value.detach().numpy(), ax=ax, vmin=-0.5, vmax=0.5, cbar=True)
            ax.set_xticks([])
            ax.set_yticks([])
            ax.set_title("Predicted Solution")
            plt.show()
        
        def plot_true(self):
            weidu = torch.linspace(0, math.pi, 200, requires_grad=False)
            jingdu = torch.linspace(0, 2 * math.pi, 400, requires_grad=False)
            weidu, jingdu = torch.meshgrid(weidu, jingdu)
            location = torch.cat([weidu.reshape(-1, 1), jingdu.reshape(-1, 1)], dim=1)
            value = true_solution(location[:, 0:1], location[:, 1:])
            
            value = value.reshape((200, 400))
            
            fig, ax = plt.subplots(1, 1, figsize=(8, 6))
            sns.set()
            sns.heatmap(value.detach().numpy(), ax=ax, vmin=-0.5, vmax=0.5, cbar=True)
            ax.set_xticks([])
            ax.set_yticks([])
            ax.set_title("True Solution")
            plt.show()
            
        def post_process(self, ax=None):
            if ax is None:
                plt.plot(self.loss_history)
                plt.yscale('log')
                plt.legend(('BC loss', 'pde loss', 'predict error'))
                plt.show()
            else:
                ax.plot(self.loss_history)
                ax.set_yscale('log')
                ax.set_ylim(1e-4, 100)
                ax.legend(('BC loss', 'pde loss', 'predict error'))

        def predict_error(self):
            coor = self.inner_sample(num=500)
            true = self.problem.ground_truth(coor)
            predict = self.net(coor)
            predict_error = self.pde_loss_f(true, predict)
            return predict_error

        def train(self, ax100=None):
            problem = self.problem
            net = self.net
            opt = self.opt
            maxiter = self.maxiter

            for iter in range(maxiter):
                net.zero_grad()

                coor_inner = self.inner_sample().detach().requires_grad_(True)
                infer_value_inner = net(coor_inner)
                truth_inner, predict_inner = problem.pde(coor_inner, infer_value_inner)
                self.pde_loss = self.pde_loss_f(predict_inner, truth_inner)

                bc_samples = self.bc_sample()
                if bc_samples is None:
                    self.bc_loss = torch.tensor(0.)
                else:
                    coor_bc = bc_samples.detach().requires_grad_(True)
                    infer_value_bc = net(coor_bc)
                    truth_bc, predict_bc = problem.bound_condition(coor_bc, infer_value_bc)
                    self.bc_loss = self.bc_loss_f(predict_bc, truth_bc)

                init_samples = self.init_sample()
                if init_samples is None:
                    self.init_loss = torch.tensor(0.)
                else:
                    coor_init = init_samples.detach().requires_grad_(True)
                    infer_value_init = net(coor_init)
                    truth_init, predict_init = problem.bound_condition(coor_init, infer_value_init)
                    self.init_loss = self.bc_loss_f(predict_init, truth_init)
                self.predict_error_value = self.predict_error()
                self.total_loss = self.pde_loss + self.bc_loss + self.init_loss
                self.add_loss_history()
                self.total_loss.backward()

                opt.step()
                opt.zero_grad()
                
                for i in range(len(self.loss_history)):
                    for j in range(3):
                        self.loss_history[i][j] = self.loss_history[i][j].detach().requires_grad_(False)
                        
                if iter % (maxiter // 100) == 0:
                    print("iteration {}: loss = {}".format(iter, self.total_loss))
                        
                if iter % int(maxiter / 10) == 0:
                    self.plot(net)
                
            self.plot(net)
            self.plot_true()
            self.post_process()

    return Poisson1dModel()

model = construct_model(Sphere_Net([3, 50, 50, 50, 16, 1]))
model.train()
# Out:
# tensor([[1., 1.]], requires_grad=True)
# iteration 0: loss = 12.171613693237305
# tensor([[1., 1.]], requires_grad=True)
# iteration 1: loss = 11.368891716003418
# tensor([[1., 1.]], requires_grad=True)
# iteration 2: loss = 10.291796684265137
# tensor([[1., 1.]], requires_grad=True)
# iteration 3: loss = 11.394064903259277
# tensor([[1., 1.]], requires_grad=True)
# iteration 4: loss = 11.873055458068848
# tensor([[1., 1.]], requires_grad=True)
# iteration 5: loss = 11.297657012939453
# tensor([[1., 1.]], requires_grad=True)
# iteration 6: loss = 11.195352554321289
# tensor([[1., 1.]], requires_grad=True)
# iteration 7: loss = 11.400105476379395
# tensor([[1., 1.]], requires_grad=True)
# iteration 8: loss = 10.881125450134277
# tensor([[1., 1.]], requires_grad=True)
# iteration 9: loss = 11.717623710632324
# tensor([[1., 1.]], requires_grad=True)
# iteration 10: loss = 10.578079223632812
# tensor([[1., 1.]], requires_grad=True)
# iteration 11: loss = 11.025038719177246
# tensor([[1., 1.]], requires_grad=True)
# iteration 12: loss = 10.72822380065918
# tensor([[1., 1.]], requires_grad=True)
# iteration 13: loss = 10.682832717895508
# tensor([[1., 1.]], requires_grad=True)
# iteration 14: loss = 10.522026062011719
# tensor([[1., 1.]], requires_grad=True)
# iteration 15: loss = 11.22327995300293
# tensor([[1., 1.]], requires_grad=True)
# iteration 16: loss = 10.265828132629395
# tensor([[1., 1.]], requires_grad=True)
# iteration 17: loss = 10.199365615844727
# tensor([[1., 1.]], requires_grad=True)
# iteration 18: loss = 10.030911445617676
# tensor([[1., 1.]], requires_grad=True)
# iteration 19: loss = 10.377720832824707
# tensor([[1., 1.]], requires_grad=True)
# iteration 20: loss = 10.07710075378418
# tensor([[1., 1.]], requires_grad=True)
# iteration 21: loss = 9.58006477355957
# tensor([[1., 1.]], requires_grad=True)
# iteration 22: loss = 9.550500869750977
# tensor([[1., 1.]], requires_grad=True)
# iteration 23: loss = 8.77153205871582
# tensor([[1., 1.]], requires_grad=True)
# iteration 24: loss = 9.494403839111328
# tensor([[1., 1.]], requires_grad=True)
# iteration 25: loss = 8.836103439331055
# tensor([[1., 1.]], requires_grad=True)
# iteration 26: loss = 8.3537015914917
# tensor([[1., 1.]], requires_grad=True)
# iteration 27: loss = 8.157512664794922
# tensor([[1., 1.]], requires_grad=True)
# iteration 28: loss = 8.209723472595215
# tensor([[1., 1.]], requires_grad=True)
# iteration 29: loss = 7.129453659057617
# tensor([[1., 1.]], requires_grad=True)
# iteration 30: loss = 7.084847927093506
# tensor([[1., 1.]], requires_grad=True)
# iteration 31: loss = 6.686174392700195
# tensor([[1., 1.]], requires_grad=True)
# iteration 32: loss = 6.343327045440674
# tensor([[1., 1.]], requires_grad=True)
# iteration 33: loss = 5.811267375946045
# tensor([[1., 1.]], requires_grad=True)
# iteration 34: loss = 5.135119438171387
# tensor([[1., 1.]], requires_grad=True)
# iteration 35: loss = 4.574521064758301
# tensor([[1., 1.]], requires_grad=True)
# iteration 36: loss = 4.064608573913574
# tensor([[1., 1.]], requires_grad=True)
# iteration 37: loss = 3.560673236846924
# tensor([[1., 1.]], requires_grad=True)
# iteration 38: loss = 3.143298864364624
# tensor([[1., 1.]], requires_grad=True)
# iteration 39: loss = 2.8109185695648193
# tensor([[1., 1.]], requires_grad=True)
# iteration 40: loss = 2.3650319576263428
# tensor([[1., 1.]], requires_grad=True)
# iteration 41: loss = 1.957476019859314
# tensor([[1., 1.]], requires_grad=True)
# iteration 42: loss = 1.6303614377975464
# tensor([[1., 1.]], requires_grad=True)
# iteration 43: loss = 1.3822728395462036
# tensor([[1., 1.]], requires_grad=True)
# iteration 44: loss = 1.2291001081466675
# tensor([[1., 1.]], requires_grad=True)
# iteration 45: loss = 1.0542408227920532
# tensor([[1., 1.]], requires_grad=True)
# iteration 46: loss = 0.9582911133766174
# tensor([[1., 1.]], requires_grad=True)
# iteration 47: loss = 0.9041793346405029
# tensor([[1., 1.]], requires_grad=True)
# iteration 48: loss = 0.9507054090499878
# tensor([[1., 1.]], requires_grad=True)
# iteration 49: loss = 0.8580920100212097
# tensor([[1., 1.]], requires_grad=True)
# iteration 50: loss = 0.7218108177185059
# tensor([[1., 1.]], requires_grad=True)
# iteration 51: loss = 0.676582932472229
# tensor([[1., 1.]], requires_grad=True)
# iteration 52: loss = 0.6076877117156982
# tensor([[1., 1.]], requires_grad=True)
# iteration 53: loss = 0.5395417809486389
# tensor([[1., 1.]], requires_grad=True)
# iteration 54: loss = 0.44125500321388245
# tensor([[1., 1.]], requires_grad=True)
# iteration 55: loss = 0.34757739305496216
# tensor([[1., 1.]], requires_grad=True)
# iteration 56: loss = 0.32954588532447815
# tensor([[1., 1.]], requires_grad=True)
# iteration 57: loss = 0.29624372720718384
# tensor([[1., 1.]], requires_grad=True)
# iteration 58: loss = 0.3013058602809906
# tensor([[1., 1.]], requires_grad=True)
# iteration 59: loss = 0.32519060373306274
# tensor([[1., 1.]], requires_grad=True)
# iteration 60: loss = 0.32533717155456543
# tensor([[1., 1.]], requires_grad=True)
# iteration 61: loss = 0.3119851052761078
# tensor([[1., 1.]], requires_grad=True)
# iteration 62: loss = 0.36435213685035706
# tensor([[1., 1.]], requires_grad=True)
# iteration 63: loss = 0.36774542927742004
# tensor([[1., 1.]], requires_grad=True)
# iteration 64: loss = 0.38030940294265747
# tensor([[1., 1.]], requires_grad=True)
# iteration 65: loss = 0.35660481452941895
# tensor([[1., 1.]], requires_grad=True)
# iteration 66: loss = 0.36656489968299866
# tensor([[1., 1.]], requires_grad=True)
# iteration 67: loss = 0.34288927912712097
# tensor([[1., 1.]], requires_grad=True)
# iteration 68: loss = 0.27085191011428833
# tensor([[1., 1.]], requires_grad=True)
# iteration 69: loss = 0.2866387963294983
# tensor([[1., 1.]], requires_grad=True)
# iteration 70: loss = 0.23284216225147247
# tensor([[1., 1.]], requires_grad=True)
# iteration 71: loss = 0.23784610629081726
# tensor([[1., 1.]], requires_grad=True)
# iteration 72: loss = 0.2136775404214859
# tensor([[1., 1.]], requires_grad=True)
# iteration 73: loss = 0.18380418419837952
# tensor([[1., 1.]], requires_grad=True)
# iteration 74: loss = 0.17985139787197113
# tensor([[1., 1.]], requires_grad=True)
# iteration 75: loss = 0.1914299875497818
# tensor([[1., 1.]], requires_grad=True)
# iteration 76: loss = 0.18339447677135468
# tensor([[1., 1.]], requires_grad=True)
# iteration 77: loss = 0.1729591190814972
# tensor([[1., 1.]], requires_grad=True)
# iteration 78: loss = 0.16948239505290985
# tensor([[1., 1.]], requires_grad=True)
# iteration 79: loss = 0.1805305927991867
# tensor([[1., 1.]], requires_grad=True)
# iteration 80: loss = 0.16582158207893372
# tensor([[1., 1.]], requires_grad=True)
# iteration 81: loss = 0.17689357697963715
# tensor([[1., 1.]], requires_grad=True)
# iteration 82: loss = 0.16290713846683502
# tensor([[1., 1.]], requires_grad=True)
# iteration 83: loss = 0.1490783989429474
# tensor([[1., 1.]], requires_grad=True)
# iteration 84: loss = 0.15497413277626038
# tensor([[1., 1.]], requires_grad=True)
# iteration 85: loss = 0.1437903195619583
# tensor([[1., 1.]], requires_grad=True)
# iteration 86: loss = 0.15191902220249176
# tensor([[1., 1.]], requires_grad=True)
# iteration 87: loss = 0.14001381397247314
# tensor([[1., 1.]], requires_grad=True)
# iteration 88: loss = 0.12942051887512207
# tensor([[1., 1.]], requires_grad=True)
# iteration 89: loss = 0.15920042991638184
# tensor([[1., 1.]], requires_grad=True)
# iteration 90: loss = 0.1421157866716385
# tensor([[1., 1.]], requires_grad=True)
# iteration 91: loss = 0.14190997183322906
# tensor([[1., 1.]], requires_grad=True)
# iteration 92: loss = 0.1344827562570572
# tensor([[1., 1.]], requires_grad=True)
# iteration 93: loss = 0.14430761337280273
# tensor([[1., 1.]], requires_grad=True)
# iteration 94: loss = 0.13730119168758392
# tensor([[1., 1.]], requires_grad=True)
# iteration 95: loss = 0.12266816943883896
# tensor([[1., 1.]], requires_grad=True)
# iteration 96: loss = 0.12442227452993393
# tensor([[1., 1.]], requires_grad=True)
# iteration 97: loss = 0.11152056604623795
# tensor([[1., 1.]], requires_grad=True)
# iteration 98: loss = 0.11991038173437119
# tensor([[1., 1.]], requires_grad=True)
# iteration 99: loss = 0.11289245635271072
# tensor([[1., 1.]], requires_grad=True)
# iteration 100: loss = 0.11342262476682663
